# %%
#turns data into a spreadsheet dataframe
import pandas as pd
#a number array that works with pandas
#used to manipulate data and arrays
import numpy as np
#to plot the data
import matplotlib.pyplot as plt

#print the matplot on this page
# %matplotlib inline

#urlopen to open up the website
from urllib.request import urlopen
from bs4 import BeautifulSoup
#to manipulate regex and reformatting
import re

# %%
import urllib.request

# %%
sauce = urllib.request.urlopen('https://www.hubertiming.com/results/2018MLK').read()

soup = BeautifulSoup(sauce, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="Race results for the 2018 MLK Dream Run!" property="og:title"/>
# <meta content="Results of the 2018 MLK Dream Run at Soul District in Portland, OR" property="og:description"/>
# <meta content="https://www.hubertiming.com/results/2018MLKDreamRun.jpg" property="og:image"/>
# <meta content="https://www.hubertiming.com/results/2018mlk" property="og:url"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>Race results for the 2018 MLK Dream Run!</title>
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://use.fontawesome.com/releases/v5.13.0/css/all.css" rel="stylesheet"/>
# <link href="//cdn.rawgit.com/noelboss/featherlight/1.7.11/release/featherlight.min.css" rel="stylesheet" type="text/css"/>
# ...

# %%
for paragraph in soup.find_all('p'):
    print(paragraph.text)
# Out:
#  2018 MLK Dream Run 5K
#  Soul District, Portland, OR
#  September 23rd, 2018
#
#
#
#  MLK Dream Run
#
#
#
#
#  Email
#                         timing@hubertiming.com with results questions. Please include your bib number if you have it.
#
#
#
#
# Huber Timing Home

# %%
for links in soup.find_all('a'):
    print(links.get_text('href'))
# Out:
# MLK Dream Run
# timing@hubertiming.com
# Huber Timing Home
#  10K
#  15K
#  Summary
#
# 5K Results
# Huber Timing
#
# Dark Mode

# %%
for links in soup.find_all('a'):
    print(links.get('href'))
# Out:
# https://www.mlkdreamrun.com/
# mailto:timing@hubertiming.com
# https://www.hubertiming.com
# /results/2018MLK10K
# /results/2018MLK15K
# /results/summary/2018MLK
# None
# #tabs-1
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/
# None

# %%
for tables in soup.find_all('table'):
    print(tables.text)
# Out:
# 5K:
#
#
# Finishers:
# 191
#
#
# Male:
# 78
#
#
# Female:
# 113
#
#
#
#
#
#
# Place
# Bib
# Name
# Gender
# Age
# City
# State
# Chip Pace
# Chip Time
# Gender Place
# Age Group
# Age Group Place
# Time to Start
# Gun Time
#
#
#
#
# 1
# 1191
#
#
#                     MAX RANDOLPH
#
#
# M
# 29
# WASHINGTON
# DC
# 5:25
# 16:48
#
#
#                     1 of 78
#
#
# M 21-39
#
#
#                     1 of 33
#
#
# 0:08
# 16:56
#
#
# 2
# 1080
#
#
#                     NEED NAME KAISER RUNNER
#
#
# M
# 25
# PORTLAND
# OR
# 5:39
# 17:31
#
#
#                     2 of 78
#
#
# M 21-39
#
#
#                     2 of 33
#
#
# 0:09
# 17:40
#
#
# 3
# 1275
#
#
#                     DAN FRANEK
#
#
# M
# 52
# PORTLAND
# OR
# 5:53
# 18:15
#
#
#                     3 of 78
#
#
# M 40-54
#
#
#                     1 of 27
#
#
# 0:07
# 18:22
#
#
# 4
# 1223
#
#
#                     PAUL TAYLOR
#
#
# M
# 54
# PORTLAND
# OR
# 5:58
# 18:31
#
#
#                     4 of 78
#
#
# M 40-54
#
#
# ...

# %%
tables = soup.find_all('table')
table_rows = tables.find_all('tr')
for rows in table_rows:
    table_data = rows.find_all('td')
    row = [i.text for i in table_data]
    print(row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27356\2333947246.py in <module>
#       1 tables = soup.find_all('table')
# ----> 2 table_rows = tables.find_all('tr')
#       3 for rows in table_rows:
#       4     table_data = rows.find_all('td')
#       5     row = [i.text for i in table_data]
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2287     def __getattr__(self, key):
#    2288         """Raise a helpful exception to explain a common code fix."""
# -> 2289         raise AttributeError(
#    2290             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291         )
#
# ...

# %%
tables = soup.find('table')
table_rows = tables.find_all('tr')
for tr in table_rows:
    td = rows.find_all('td')
    row = [i.text for i in td]
    print(row)

# %%
tables = soup.find('table')
table_rows = tables.find_all('tr')
for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)

# %%
dfs = pd.read_html('https://www.hubertiming.com/results/2018MLK')
for df in dfs:
    print(df)

# %%
tables = soup.find('table')
table_rows = tables.find_all('tr')
for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)

# %%
dfs = pd.read_html('https://www.hubertiming.com/results/2018MLK')
for df in dfs:
    print(df)

# %%
dfs = pd.read_html('https://www.hubertiming.com/results/2018MLK')
for df in dfs:
    print(df.head)

# %%
dfs = pd.read_html('https://www.hubertiming.com/results/2018MLK',header=0)
for df in dfs:
    print(df)

# %%
dfs = pd.read_html('https://pythonprogramming.net/parsememcparseface/')
for df in dfs:
    print(df)

# %%
dfs = pd.read_html('https://pythonprogramming.net/parsememcparseface/', header = 0)
for df in dfs:
    print(df)

# %%
sauce = urllib.request.urlopen('https://pythonprogramming.net/sitemap.xml').read()

soup = BeautifulSoup(sauce, 'xml')
print(soup)

# %%
sauce = urllib.request.urlopen('https://pythonprogramming.net/sitemap.xml').read()

soup = BeautifulSoup(sauce, 'xml')
for links in soup.find_all('loc'):
    print(links.text)

# %%
sauce = urllib.request.urlopen('https://pythonprogramming.net/parsememcparseface/').read()
soup = BeautifulSoup(sauce,'lxml')
table = soup.table
table_rows = tables.find_all('tr')
for rows in table_rows:
    table_data = rows.find_all('td')
    row = [i.text for i in table_data]
    print(row)

# %%
sauce = urllib.request.urlopen('https://pythonprogramming.net/parsememcparseface/').read()
soup = BeautifulSoup(sauce,'lxml')
table = soup.table
table_rows = table.find_all('tr')
for rows in table_rows:
    table_data = rows.find_all('td')
    row = [i.text for i in table_data]
    print(row)

# %%
js_test = soup.find('p', class_='jstest')
print(js_test.text)
